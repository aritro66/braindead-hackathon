# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv = pd.read_csv('Placement_Data_Full_Class.csv', index_col=0)
csv
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ...      ...    ...      ...    ...      ...       ...       ...        ...
# 211        M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 212        M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 213        M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 214        F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 215        M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
# ...

# %%
##replace null with 0 
csv['salary'].fillna(0, inplace=True)

# %%
##show correlation between features only wrt status
corr = csv.corr()

corr = corr['status']

corr
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\Admin\miniconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Admin\miniconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'status'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
csv.groupby('status')['etest_p'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# status
# 0        67.0  69.587910  11.930687  50.0  60.0  67.0  76.5  97.0
# 1       148.0  73.238041  13.729333  50.0  60.0  72.0  85.0  98.0

# %%
##boxplot of etest_p wrt status
sns.boxplot(x='status', y='etest_p', data=csv)
# Out:
# <AxesSubplot:xlabel='status', ylabel='etest_p'>

# %%
##perform hypothesis testing to check if etest_p is significant wrt status

##H0: etest_p is not significant wrt status
##H1: etest_p is significant wrt status

##alpha = 0.05

##since etest_p is continuous, we will use ANOVA test

##ANOVA test

##H0: etest_p is not significant wrt status
##H1: etest_p is significant wrt status

# %%
##check the sampling distribution of etest_p wrt status

# %%
alpha = 0.05

from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols


from scipy.stats import levene

levene(csv['etest_p'][csv['status'] == 'Placed'], csv['etest_p'][csv['status'] == 'Not Placed'])
# Out:
#               df        sum_sq     mean_sq         F   PR(>F)
# C(status)    1.0    614.489894  614.489894  3.527627  0.06172
# Residual   213.0  37103.228039  174.193559       NaN      NaN

# %%
# draw a line plot for etest_p
sns.lineplot(x='etest_p', y='salary', data=csv)
# Out:
# <AxesSubplot:xlabel='etest_p', ylabel='salary'>

# %%
##create a numpy array for gender and status

obs =  np.array([csv['gender'],csv['status']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Admin\Documents\dsml\braindead_hackathon\q1.ipynb Cell 12 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Documents/dsml/braindead_hackathon/q1.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> ##create a numpy array for gender and status
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Documents/dsml/braindead_hackathon/q1.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> obs =  np.array([csv['gender'],csv['status']])
#
# NameError: name 'np' is not defined

# %%
##check if gender is significant wrt status

##perform two way chi square test

from scipy.stats import chi2_contingency

res = chi2_contingency()
